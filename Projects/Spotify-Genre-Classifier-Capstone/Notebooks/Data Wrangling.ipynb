# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pandas_profiling import ProfileReport

# %%
# Reads the csv file data of spotify songs and its features
filename = '../Datasets/SpotifyFeatures.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %%
# Examnines the genre column
print('Genre: \n', df.genre.value_counts(), '\n')
print('Genre: \n', df.genre.unique(), '\n')
# Out:
# Genre:
#  Comedy              9681
# Soundtrack          9646
# Indie               9543
# Jazz                9441
# Pop                 9386
# Electronic          9377
# Children’s Music    9353
# Folk                9299
# Hip-Hop             9295
# Rock                9272
# Alternative         9263
# Classical           9256
# Rap                 9232
# World               9096
# Soul                9089
# Blues               9023
# R&B                 8992
# Anime               8936
# Reggaeton           8927
# Ska                 8874
# Reggae              8771
# Dance               8701
# Country             8664
# Opera               8280
# Movie               7806
# Children's Music    5403
# A Capella            119
# Name: genre, dtype: int64
#
# Genre:
#  ['Movie' 'R&B' 'A Capella' 'Alternative' 'Country' 'Dance' 'Electronic'
#  'Anime' 'Folk' 'Blues' 'Opera' 'Hip-Hop' "Children's Music"
#  'Children’s Music' 'Rap' 'Indie' 'Classical' 'Pop' 'Reggae' 'Reggaeton'
# ...

# %%
# Examines songs in the 'Movie' genre
df.loc[df.genre == 'Movie',:]
# Out:
#         genre        artist_name  \
# 0       Movie     Henri Salvador
# 1       Movie  Martin & les fées
# 2       Movie    Joseph Williams
# 3       Movie     Henri Salvador
# 4       Movie       Fabien Nataf
# ...       ...                ...
# 196507  Movie    Joseph Williams
# 196508  Movie      Bernard Minet
# 196509  Movie             Chorus
# 196510  Movie       Randy Newman
# 196511  Movie             Amalya
#
#                                                track_name  \
# 0                             C'est beau de faire un Show
# 1                        Perdu d'avance (par Gad Elmaleh)
# 2                          Don't Let Me Be Lonely Tonight
# 3                          Dis-moi Monsieur Gordon Cooper
# 4                                               Ouverture
# ...                                                   ...
# 196507                             A Whiter Shade Of Pale
# 196508                                 Bioman - Générique
# ...

# %%
# Deletes the 'Movie' genre rows as it is not a good genre specifier
df = df[df.genre != 'Movie']
df.genre.unique()
# Out:
# array(['R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
# Checks data types of columns
df.dtypes
# Out:
# genre                object
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# time_signature       object
# valence             float64
# dtype: object

# %%
df['genre'].unique()
# Out:
# array(['R&B', 'A Capella', 'Alternative', 'Country', 'Dance',
#        'Electronic', 'Anime', 'Folk', 'Blues', 'Opera', 'Hip-Hop',
#        "Children's Music", 'Children’s Music', 'Rap', 'Indie',
#        'Classical', 'Pop', 'Reggae', 'Reggaeton', 'Jazz', 'Rock', 'Ska',
#        'Comedy', 'Soul', 'Soundtrack', 'World'], dtype=object)

# %%
# Changes label of genre "Children's Music" with "" to '' to convert duplicate label under one label
df['genre'] = df['genre'].str.replace("Children's Music", "Children’s Music")
print(df['genre'].nunique(), "unique values: ", df['genre'].unique())
# Out:
# 25 unique values:  ['R&B' 'A Capella' 'Alternative' 'Country' 'Dance' 'Electronic' 'Anime'
#  'Folk' 'Blues' 'Opera' 'Hip-Hop' 'Children’s Music' 'Rap' 'Indie'
#  'Classical' 'Pop' 'Reggae' 'Reggaeton' 'Jazz' 'Rock' 'Ska' 'Comedy'
#  'Soul' 'Soundtrack' 'World']

# %%
# Gets the unique values in several categorical and numerical columns with a low count of distinct values
print('Genre: \n', df.genre.unique())
print('\nKey: \n', df.key.unique())
print('\nTime Signature: \n', df.time_signature.unique())
print('\nMode: \n', df["mode"].unique(), '\n')
# Out:
# Genre:
#  ['R&B' 'A Capella' 'Alternative' 'Country' 'Dance' 'Electronic' 'Anime'
#  'Folk' 'Blues' 'Opera' 'Hip-Hop' 'Children’s Music' 'Rap' 'Indie'
#  'Classical' 'Pop' 'Reggae' 'Reggaeton' 'Jazz' 'Rock' 'Ska' 'Comedy'
#  'Soul' 'Soundtrack' 'World']
#
# Key:
#  ['D' 'C' 'F' 'B' 'E' 'G' 'G#' 'A#' 'C#' 'A' 'F#' 'D#']
#
# Time Signature:
#  ['4/4' '3/4' '5/4' '1/4' '0/4']
#
# Mode:
#  ['Minor' 'Major']

# %%
# Calculates the median, mode, standard deviation of each of the 11 numerical columns
print('popularity: \n', "median: ", df['popularity'].median(), " mode:", df['popularity'].mode(), "std:", df['popularity'].std())
print('\nacousticness: \n', "median: ", df['acousticness'].median(), " mode:", df['acousticness'].mode(), "std:", df['acousticness'].std())
print('\ndanceability: \n', "median: ", df['danceability'].median(), " mode:", df['danceability'].mode(), "std:", df['danceability'].std())
print('\nduration_ms: \n', "median: ", df['duration_ms'].median(), " mode:", df['duration_ms'].mode(), "std:", df['duration_ms'].std())
print('\nenergy: \n', "median: ", df['energy'].median(), " mode:", df['energy'].mode(), "std:", df['energy'].std())
print('\ninstrumentalness: \n', "median: ", df['instrumentalness'].median(), " mode:", df['instrumentalness'].mode(), "std:", df['instrumentalness'].std())
print('\nliveness: \n', "median: ", df['liveness'].median(), " mode:", df['liveness'].mode(), "std:", df['liveness'].std())
print('\nloudness: \n', "median: ", df['loudness'].median(), " mode:", df['loudness'].mode(), "std:", df['loudness'].std())
print('\nspeechiness: \n', "median: ", df['speechiness'].median(), " mode:", df['speechiness'].mode(), "std:", df['speechiness'].std())
print('\ntempo: \n', "median: ", df['tempo'].median(), " mode:", df['tempo'].mode(), "std:", df['tempo'].std())
print('\nvalence: \n', "median: ", df['valence'].median(), " mode:", df['valence'].mode(), "std:", df['valence'].std())
# Out:
# popularity:
#  median:  44.0  mode: 0    53
# dtype: int64 std: 17.487793638151285
#
# acousticness:
#  median:  0.21600000000000003  mode: 0    0.995
# dtype: float64 std: 0.35167706648943226
#
# danceability:
#  median:  0.573  mode: 0    0.597
# dtype: float64 std: 0.18545232652268254
#
# duration_ms:
#  median:  221387.0  mode: 0    240000
# dtype: int64 std: 114234.1463242093
#
# energy:
#  median:  0.614  mode: 0    0.721
# dtype: float64 std: 0.26157118554535336
#
# instrumentalness:
#  median:  4.7e-05  mode: 0    0.0
# dtype: float64 std: 0.30343474081654914
#
# liveness:
#  median:  0.128  mode: 0    0.111
# dtype: float64 std: 0.19829119729478722
#
# loudness:
#  median:  -7.643  mode: 0   -5.318
# dtype: float64 std: 5.976155633206901
#
# speechiness:
#  median:  0.0504  mode: 0    0.0337
# dtype: float64 std: 0.18572328191291343
#
# tempo:
#  median:  115.97  mode: 0    120.016
# dtype: float64 std: 30.909935166135575
#
# valence:
#  median:  0.445  mode: 0    0.961
# ...

# %%
# Gives a profile of the data
profile = ProfileReport(df, title="Pandas Profiling Report")
profile.to_widgets()

# %%
# Popularity distribution plot
plot = df['popularity'].plot.kde()
plt.xlabel('Popularity')
sns.displot(df['popularity'])
plt.xlabel('Popularity')
# Out:
# Text(0.5, 6.79999999999999, 'Popularity')

# %%
# Acousticness distribution plot
plot = df['acousticness'].plot.kde()
plt.xlabel('Acousticness')
sns.displot(df['acousticness'])
plt.xlabel('Acousticness')
# Out:
# Text(0.5, 6.79999999999999, 'Acousticness')

# %%
# Danceability distribution plot
plot = df['danceability'].plot.kde()
plt.xlabel('Danceability')
sns.displot(df['danceability'])
plt.xlabel('Danceability')
# Out:
# Text(0.5, 6.79999999999999, 'Danceability')

# %%
# Duration distribution plots
plot = df['duration_ms'].plot.kde()
plt.xlabel('Duration (ms)')
sns.displot(df['duration_ms'])
plt.xlabel('Duration (ms)')
# Out:
# Text(0.5, 6.79999999999999, 'Duration (ms)')

# %%
# Energy distribution plots
plot = df['energy'].plot.kde()
plt.xlabel('Energy')
sns.displot(df['energy'])
plt.xlabel('Energy')
# Out:
# Text(0.5, 6.79999999999999, 'Energy')

# %%
# Instrumentalness distribution plots
plot = df['instrumentalness'].plot.kde()
plt.xlabel('Instrumentalness')
sns.displot(df['instrumentalness'])
plt.xlabel('Instrumentalness')
# Out:
# Text(0.5, 6.79999999999999, 'Instrumentalness')

# %%
# Liveness distribution plots
plot = df['liveness'].plot.kde()
plt.xlabel('Liveness')
sns.displot(df['liveness'])
plt.xlabel('Liveness')
# Out:
# Text(0.5, 6.79999999999999, 'Liveness')

# %%
# Loudness distribution plots
df['loudness'].plot.kde()
plt.xlabel('Loudness')
sns.displot(df['loudness'])
plt.xlabel('Loudness')
# Out:
# Text(0.5, 6.79999999999999, 'Loudness')

# %%
# Speechiness distribution plots
df['speechiness'].plot.kde()
plt.xlabel('Speechiness')
sns.displot(df['speechiness'])
plt.xlabel('Speechiness')
# Out:
# Text(0.5, 6.79999999999999, 'Speechiness')

# %%
# Tempo distribution plots
df['tempo'].plot.kde()
plt.xlabel('Tempo')
sns.displot(df['tempo'])
plt.xlabel('Tempo')
# Out:
# Text(0.5, 6.79999999999999, 'Tempo')

# %%
# Valence Distribution plots
df['valence'].plot.kde()
plt.xlabel('Valence')
sns.displot(df['valence'])
plt.xlabel('Valence')
# Out:
# Text(0.5, 6.79999999999999, 'Valence')

# %%
df.to_csv('cleaned_data.csv', index = False)

# %% [markdown]
# Some key details according to the profile report & more data wrangling:
# - There are no duplicate rows.
# - There are no null values in any cell.
# - There are 232,725 rows and 18 columns (7 categorical and 11 numerical).
#     - 7 categorical: genre, artist_name, track_name, track_id, key, mode, time_signature
#     - 11 numerical: popularity, acousticness, danceability, duration_ms, energy, instrumentalness, liveness, loudness, speechiness, tempo, valence
#     - genre: There are 25 genres of music
#     - artist_name: Name of artist
#     - track_name: Name of track
#     - track_id: ID of track
#     - key: The key or pitch the track is in
#     - mode: Modality of track, the type of scale from which its melodic content is derived
#     - time_signature: An estimated overall time signature of a track. The time signature (meter) is a notational convention to specify how many beats are in each bar (or measure)
#     - popularity: Scale: [0, 100]. The popularity of the tracked with users on Spotify. 0 to 100 is increase in popularity.
#     - acousticness: Scale: [0.0, 1.0]. A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
#     - danceability: Scale: [0.0, 1.0]. Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#     - duration_ms: The duration of the track in milliseconds.
#     - energy: Scale: [0.0, 1.0]. It represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
#     - instrumentalness: Scale: [0.0, 1.0]. Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#     - liveliness: Detects the presence of an audience in the recording. Higher liveness values represent an increased probability that the track was performed live. A value above 0.8 provides strong likelihood that the track is live.
#     - loudness: Scale: [-60, 0]. The overall loudness of a track in decibels (dB).
#     - speechiness: Scale: [0.0, 1.0]. Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#     - tempo: The overall estimated tempo of a track in beats per minute (BPM).
#     - valence: Scale: [0.0, 1.0]. Describes the musical positivenss conveyed by the track. High valence is mose Tracks with high valence sound more positive (e.g. happy, cheerful, euphoric), while tracks with low valence sound more negative (e.g. sad, depressed, angry).
